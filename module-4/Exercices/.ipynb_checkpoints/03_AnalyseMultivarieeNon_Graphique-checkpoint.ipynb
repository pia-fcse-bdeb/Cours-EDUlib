# %% [markdown]
# <a href="https://colab.research.google.com/github/pia-fcse-bdeb/Cours-EDUlib/blob/master/module-4/Exercices/03_AnalyseMultivarieeNon_Graphique.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>
#
# # **Analyse multivariée non-graphique**

# %% [markdown]
# **Objectifs d'apprentissage :**
#   * Introduction à l'exploration multivariée non-graphique
#   * Techniques d'exploration multivariée non-graphique
#   * Exemple pratique d'exploration multivariée à l'aide de la matrice de corrélation

# %% [markdown]
#   ## **Introduction à l'exploration multivariée non-graphique**
#  L'exploration multivariée non-graphique s'intéresse à l'analyse de deux ou plusieurs variables à la fois. Elle étudie les relations existantes entre ces variables et utilise différentes  techniques statistiques pour illustrer ces relations tel que les tableaux de contingence et les matrices de corrélation.

# %% [markdown]
#   ## **Techniques d'exploration multivariée non-graphique**
#
#
#  ### **1.   Tableau de contingence**
#
# Le tableau de contingence permet d'illustrer les fréquences représentantes des modalités croisées de deux attributs x et y. Le tableau de contingence est utilisé seulement dans le cas de variables qualitatives.
#
# ### **2. Matrice de corrélation**
#
# La matrice de corrélation permet d'illustrer les relations de dépendance entre deux attributs x et y. La matrice de corrélation est utilisée seulement dans le cas de variables quantitatives. On distingue deux types de corrélations:
#
# * **Corrélation positive:** dans ce cas les deux attributs ou variables varient dans le même sens.
#
# ![image.png](data:image/png;base64,...)
#
# * **Corrélation négative:** dans ce cas la première variable varie dans le sens inverse de la deuxième variable.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  ## **Exemple pratique d'exploration multivariée à l'aide de la matrice de corrélation**
#
# Pour l'analyse multivariée non-graphique, le module *pandas* est essentiel. Dans le cadre de cet exemple pratique, nous avons besoin également de charger les données sur le cancer du sein disponible dans le module *Scikit-Learn*. Exécutez les lignes de code suivantes pour importer les librairies nécessaires et charger ces données dans un *DataFrame*.

# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer
cancerData = load_breast_cancer()
cancer = pd.DataFrame(cancerData.data, columns=cancerData.feature_names)

# %% [markdown]
#  ## **Exercice**
#
# Utilisez la fonction *corr()* en *Python* pour afficher la matrice de corrélation pour les variables indépendantes dans les données du cancer de sein.

# %%
# Your code here

# %% [markdown]
#  ### **Solution**
#
# Exécuter la cellule suivante pour afficher la matrice de corrélation. N'oubliez pas d'exécuter les lignes de code ci-dessus avant afin de pourvoir importer les modules nécessaires ainsi que les données du cancer de sein et de charger les données dans un *DataFrame*.

# %%
cancer.corr()
# Out:
#                          mean radius  ...  worst fractal dimension
# mean radius                 1.000000  ...                 0.007066
# mean texture                0.323782  ...                 0.119205
# mean perimeter              0.997855  ...                 0.051019
# mean area                   0.987357  ...                 0.003738
# mean smoothness             0.170581  ...                 0.499316
# mean compactness            0.506124  ...                 0.687382
# mean concavity              0.676764  ...                 0.514930
# mean concave points         0.822529  ...                 0.368661
# mean symmetry               0.147741  ...                 0.438413
# mean fractal dimension     -0.311631  ...                 0.767297
# radius error                0.679090  ...                 0.049559
# texture error              -0.097317  ...                -0.045655
# perimeter error             0.674172  ...                 0.085433
# ...
